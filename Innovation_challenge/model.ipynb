# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Data Visualisation and Cleaning

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split 

#data without the target variable
X= data.drop(['median_house_value'],axis=1)
y= data['median_house_value']

# %%
# Drop duplicates based on all columns
#data_no_duplicates = data.drop_duplicates()

# Display the DataFrame without duplicates
#data_no_duplicates

# %%
#data without the target data(median_house_value)
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#the target data
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
# Select numeric columns for histograms
numeric_data = train_data.select_dtypes(include=['number'])

# Plot histograms for numeric columns
numeric_data.hist(figsize=(15, 8))
plt.suptitle('Numeric Columns Histograms', x=0.5, y=1.02, fontsize=16)
plt.show()

# Plot histogram for the 'ocean_proximity' column
plt.figure(figsize=(8, 6))
sns.countplot(x='ocean_proximity', data=train_data)
plt.title('Histogram for Ocean Proximity')
plt.xlabel('Ocean Proximity')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'train_data' is the DataFrame
# Select only numeric columns for correlation analysis
numeric_data = train_data.select_dtypes(include=['number'])

# Create a heatmap for the correlation matrix of numeric columns
plt.figure(figsize=(15, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(15,8))
train_data2 = pd.get_dummies(train_data, drop_first=True)
sns.heatmap(train_data2.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_rate"]=train_data["total_bedrooms"]/train_data["total_rooms"]
train_data["household_rooms"]=train_data["total_rooms"]/train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # some new features

# %% [markdown]
# ### LinearRegression Model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler = StandardScaler()

X_train, y_train =train_data.drop(["median_house_value"],axis=1),train_data["median_house_value"]
X_train_scalar= scaler.fit_transform(X_train)

R= LinearRegression()

R.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data =test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_data["bedroom_rate"]=test_data["total_bedrooms"]/test_data["total_rooms"]
test_data["household_rooms"]=test_data["total_rooms"]/test_data["households"]

# %%
X_test, y_test =test_data.drop(["median_house_value"],axis=1),test_data["median_house_value"]

# %%
x_test_scaler= scaler.transform(X_test)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2277     -120.61     35.10                14.0     7.979339        6.539586
# 20358    -120.77     37.42                27.0     6.856462        5.416100
# 12195    -118.37     34.05                52.0     7.355002        5.726848
# 6181     -117.78     33.90                14.0     8.738735        6.804615
# 8058     -122.27     37.77                52.0     7.720018        5.963579
# ...          ...       ...                 ...          ...             ...
# 1100     -122.27     37.91                47.0     7.565793        5.755742
# 6358     -117.71     34.09                36.0     7.877776        6.167516
# 5442     -120.55     38.46                16.0     7.275172        5.521461
# 19961    -119.67     34.44                32.0     8.071843        6.287859
# 15888    -117.54     34.11                16.0     7.656810        5.926926
#
# ...

# %%
R.score(X_test,y_test)
# Out:
# 0.685897121406633

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12466    -118.38     34.18                32.0     8.175829        6.966967
# 3230     -117.13     32.63                10.0     8.905851        7.054450
# 4802     -116.94     33.73                17.0     8.548886        6.747587
# 1377     -122.23     37.85                52.0     7.937732        6.021023
# 13380    -122.42     37.80                52.0     8.514389        7.212294
# ...          ...       ...                 ...          ...             ...
# 15492    -118.99     36.07                21.0     6.891626        5.111988
# 6092     -120.81     38.67                14.0     9.035630        7.364547
# 16675    -117.81     33.64                16.0     7.785305        5.857933
# 16424    -118.22     34.05                41.0     7.260523        6.171701
# 20409    -117.67     33.44                25.0     8.004700        6.253829
#
# ...

# %%
predictions =R.predict(X_test)

# %%
plt.scatter(y_test, predictions)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %% [markdown]
# ### Random Forest Regressor Model
# ### the one that gave the nearly best result

# %%
from sklearn.ensemble import RandomForestRegressor

F= RandomForestRegressor()

F.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
F.score(X_test, y_test)*100
# Out:
# 82.10087640542419

# %%
predictions =F.predict(X_test)

# %%
# Visualize the results
plt.scatter(y_test, predictions, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Decision Tree Regression for House Prices")
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# Train a decision tree model
tree_regressor = DecisionTreeRegressor(max_depth=800)
tree_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=800)

# %%
# Make predictions on the test set
y_pred2 = tree_regressor.predict(X_test)

# %%
tree_regressor.score(X_test, y_test)*100
# Out:
# 64.67424767327678

# %%
# Visualize the results
plt.scatter(y_test, y_pred2, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Decision Tree Regression for House Prices")
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Train a decision tree classifier
tree_classifier = DecisionTreeClassifier(max_depth=10)
tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
tree_classifier.score(X_test, y_test)*100
# Out:
# 4.135062392953266
